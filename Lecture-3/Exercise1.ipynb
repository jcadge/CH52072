# %% [markdown]
# # **Lecture 3 - Exercise 1**

# %% [markdown]
# For this exercise, you will generate a t-SNE and UMAP chemical space using the carboxylic acid anions which you generated the PCA chemical space from. I've provided the packages below and provided the lines of code you will need to run t-SNE and UMAP.

# %%
! pip install umap-learn

import pandas as pd
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE
import umap

# %% [markdown]
# Run t-SNE like this:
#
# `reducer = TSNE(n_components=2, random_state=42, perplexity=10)`
#
# `X_tsne = tsne.fit_transform(X)`
#
# And UMAP like this:
#
# `reducer = umap.UMAP(n_components=2, random_state=42, n_neighbors=15)`
#
# `X_umap = reducer.fit_transform(X)`

# %% [markdown]
# ### Task 1 - Generate t-SNE chemical space

# %% [markdown]
# ### Task 2 - Generate UMAP chemical space
