# %% [markdown]
# # **Lecture 2 - Exercise 1**

# %% [markdown]
# For this exercise, you will generate a molecular graph and a molecular fingerprint for a molecule of your choice. You can choose any molecule you wish (although, not too big!) - draw the structure in ChemDraw and copy the SMILES string into the notebook. Alternatively, you can retrieve SMILES strings for molecules using sources such as PubChem: https://pubchem.ncbi.nlm.nih.gov/.

# %% [markdown]
# ### Task 1: Import/install any packages you might need for the excerise

# %% [markdown]
# ### Task 2: Add the SMILES string for the molecule of your choice into the notebook and convert it to an RDKit mol object

# %% [markdown]
# ### Task 3: Generate a 3D weighted graph based on an adjacency and Euclidean distances

# %% [markdown]
# ### Task 4: Generate a molecular fingerprint for the molecule
